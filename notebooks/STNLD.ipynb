# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
canraw = pd.read_csv('CanalStation.csv')

# %%
canraw.head(10)
# Out:
#      WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 0  Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-00      206.0     743.0
# 1  Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-01      525.0     215.0
# 2  Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-02      962.0     113.0
# 3  Wednesday   0.0  2.0  CANAL ST_R139_N090_01-03-00     1596.0      87.0
# 4  Wednesday   0.0  2.0  CANAL ST_R139_N090_01-05-00      695.0      94.0
# 5        NaN   NaN  NaN                          NaN        NaN       NaN
# 6  Wednesday   2.0  2.0  CANAL ST_R139_N089_00-00-00      185.0     126.0
# 7  Wednesday   2.0  2.0  CANAL ST_R139_N089_00-00-01       75.0      20.0
# 8  Wednesday   2.0  2.0  CANAL ST_R139_N089_00-00-02       32.0      11.0
# 9  Wednesday   2.0  2.0  CANAL ST_R139_N089_00-03-00       32.0      18.0
#
#    TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME        DOW  Avg/TnStl  \
# 0    949.0       4.0       237.25  5/30/18 20:00        NaN        NaN
# ...

# %%
pd.DataFrame(canraw)
# Out:
#         WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 0     Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-00      206.0     743.0
# 1     Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-01      525.0     215.0
# 2     Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-02      962.0     113.0
# 3     Wednesday   0.0  2.0  CANAL ST_R139_N090_01-03-00     1596.0      87.0
# 4     Wednesday   0.0  2.0  CANAL ST_R139_N090_01-05-00      695.0      94.0
# ...         ...   ...  ...                          ...        ...       ...
# 8232     Friday   3.0  4.0  CANAL ST_R320_R120_01-00-02       16.0      59.0
# 8233     Friday  11.0  4.0  CANAL ST_R320_R120_01-00-02       15.0     314.0
# 8234     Friday  15.0  4.0  CANAL ST_R320_R120_01-00-02       36.0     451.0
# 8235     Friday  19.0  4.0  CANAL ST_R320_R120_01-00-02       87.0     212.0
# 8236     Friday  11.0  4.0  CANAL ST_R320_R120_01-00-02      103.0     189.0
#
# ...

# %%
type(canraw)
# Out:
# pandas.core.frame.DataFrame

# %%
canraw.dow.value_counts()
# Out:
# 4.0    1217
# 1.0    1203
# 6.0    1201
# 0.0    1195
# 2.0    1194
# 3.0    1191
# 5.0    1014
# Name: dow, dtype: int64

# %%
sns.barplot(x = 'dow', y = 'TRAFFIC', data = canraw);

# %%
#Enter Day of Week
Monday = (canraw.WEEKDAY == "Monday")
Tuesday = (canraw.WEEKDAY == "Tuesday")
Wednesday = (canraw.WEEKDAY == "Wednesday")
Thursday = (canraw.WEEKDAY == "Thursday")
Friday = (canraw.WEEKDAY == "Friday")
Saturday = (canraw.WEEKDAY == "Saturday")
Sunday = (canraw.WEEKDAY == "Sunday")

# %%
canraw[Monday].head(10)
# Out:
#      WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 5825  Monday   3.0  0.0  CANAL ST_R462_A043_00-00-00      105.0      40.0
# 5826  Monday   7.0  0.0  CANAL ST_R462_A043_00-00-00        4.0       3.0
# 5827  Monday  11.0  0.0  CANAL ST_R462_A043_00-00-00       32.0     488.0
# 5828  Monday  15.0  0.0  CANAL ST_R462_A043_00-00-00      104.0     868.0
# 5829  Monday  19.0  0.0  CANAL ST_R462_A043_00-00-00      324.0     524.0
# 5830  Monday  23.0  0.0  CANAL ST_R462_A043_00-00-00     1160.0     453.0
# 5831  Monday   3.0  0.0  CANAL ST_R462_A043_00-00-01      139.0      68.0
# 5832  Monday   7.0  0.0  CANAL ST_R462_A043_00-00-01        7.0       5.0
# 5833  Monday  11.0  0.0  CANAL ST_R462_A043_00-00-01       49.0     746.0
# 5834  Monday  15.0  0.0  CANAL ST_R462_A043_00-00-01      121.0    1127.0
#
#       TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME  DOW  Avg/TnStl  \
# 5825    145.0       4.0        36.25   5/14/18 1:00  NaN        NaN
# ...

# %%
sns.barplot(x = 'HOUR', y = 'TRAFFIC', data = canraw[Monday])
plt.title('Monday');

# %%
canraw[Tuesday].head(10)
# Out:
#       WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 1215  Tuesday   3.0  1.0  CANAL ST_R462_A043_00-00-00      202.0      47.0
# 1216  Tuesday   7.0  1.0  CANAL ST_R462_A043_00-00-00        8.0       3.0
# 1217  Tuesday  11.0  1.0  CANAL ST_R462_A043_00-00-00       27.0     614.0
# 1218  Tuesday  15.0  1.0  CANAL ST_R462_A043_00-00-00       99.0     937.0
# 1219  Tuesday  19.0  1.0  CANAL ST_R462_A043_00-00-00      373.0     445.0
# 1220  Tuesday  23.0  1.0  CANAL ST_R462_A043_00-00-00     1016.0     386.0
# 1221  Tuesday   3.0  1.0  CANAL ST_R462_A043_00-00-01      182.0      66.0
# 1222  Tuesday   7.0  1.0  CANAL ST_R462_A043_00-00-01       13.0       5.0
# 1223  Tuesday  11.0  1.0  CANAL ST_R462_A043_00-00-01       38.0     747.0
# 1224  Tuesday  15.0  1.0  CANAL ST_R462_A043_00-00-01      145.0    1098.0
#
#       TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME  DOW  Avg/TnStl  \
# 1215    249.0       4.0        62.25   5/15/18 1:00  NaN        NaN
# ...

# %%
sns.barplot(x = 'HOUR', y = 'TRAFFIC', data = canraw[Tuesday])
plt.title('Tuesday');

# %%
canraw[Wednesday].head(10)
# Out:
#       WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 0   Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-00      206.0     743.0
# 1   Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-01      525.0     215.0
# 2   Wednesday   0.0  2.0  CANAL ST_R139_N090_01-00-02      962.0     113.0
# 3   Wednesday   0.0  2.0  CANAL ST_R139_N090_01-03-00     1596.0      87.0
# 4   Wednesday   0.0  2.0  CANAL ST_R139_N090_01-05-00      695.0      94.0
# 6   Wednesday   2.0  2.0  CANAL ST_R139_N089_00-00-00      185.0     126.0
# 7   Wednesday   2.0  2.0  CANAL ST_R139_N089_00-00-01       75.0      20.0
# 8   Wednesday   2.0  2.0  CANAL ST_R139_N089_00-00-02       32.0      11.0
# 9   Wednesday   2.0  2.0  CANAL ST_R139_N089_00-03-00       32.0      18.0
# 10  Wednesday   2.0  2.0  CANAL ST_R139_N089_00-03-01       98.0      18.0
#
#     TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME  DOW  Avg/TnStl  \
# 0     949.0       4.0       237.25  5/30/18 20:00  NaN        NaN
# ...

# %%
sns.barplot(x = 'HOUR', y = 'TRAFFIC', data = canraw[Wednesday])
plt.title('Wednesday');

# %%
canraw[Thursday].head(10)
# Out:
#        WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 2419  Thursday   3.0  3.0  CANAL ST_R462_A043_00-00-00      239.0      39.0
# 2420  Thursday   7.0  3.0  CANAL ST_R462_A043_00-00-00       11.0       3.0
# 2421  Thursday  11.0  3.0  CANAL ST_R462_A043_00-00-00       32.0     500.0
# 2422  Thursday  15.0  3.0  CANAL ST_R462_A043_00-00-00      108.0     921.0
# 2423  Thursday  19.0  3.0  CANAL ST_R462_A043_00-00-00      371.0     518.0
# 2424  Thursday  23.0  3.0  CANAL ST_R462_A043_00-00-00     1058.0     480.0
# 2425  Thursday   3.0  3.0  CANAL ST_R462_A043_00-00-01      228.0      83.0
# 2426  Thursday   7.0  3.0  CANAL ST_R462_A043_00-00-01       13.0      11.0
# 2427  Thursday  11.0  3.0  CANAL ST_R462_A043_00-00-01       39.0     656.0
# 2428  Thursday  15.0  3.0  CANAL ST_R462_A043_00-00-01      148.0    1124.0
#
#       TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME  DOW  Avg/TnStl  \
# ...

# %%
sns.barplot(x = 'HOUR', y = 'TRAFFIC', data = canraw[Thursday])
plt.title('Thursday');

# %%
canraw[Friday].head(10)
# Out:
#      WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 7020  Friday   3.0  4.0  CANAL ST_R462_A043_00-00-00      282.0     121.0
# 7021  Friday   7.0  4.0  CANAL ST_R462_A043_00-00-00       17.0       3.0
# 7022  Friday  11.0  4.0  CANAL ST_R462_A043_00-00-00       37.0     472.0
# 7023  Friday  15.0  4.0  CANAL ST_R462_A043_00-00-00      121.0     923.0
# 7024  Friday  19.0  4.0  CANAL ST_R462_A043_00-00-00      454.0     607.0
# 7025  Friday  11.0  4.0  CANAL ST_R462_A043_00-00-00      952.0     564.0
# 7026  Friday   3.0  4.0  CANAL ST_R462_A043_00-00-01      336.0     119.0
# 7027  Friday   7.0  4.0  CANAL ST_R462_A043_00-00-01       37.0       8.0
# 7028  Friday  11.0  4.0  CANAL ST_R462_A043_00-00-01       37.0     644.0
# 7029  Friday  15.0  4.0  CANAL ST_R462_A043_00-00-01      156.0    1127.0
#
#       TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME  DOW  Avg/TnStl  \
# 7020    403.0       4.0       100.75   5/18/18 1:00  NaN        NaN
# ...

# %%
sns.barplot(x = 'HOUR', y = 'TRAFFIC', data = canraw[Friday])
plt.title('Friday');

# %%
canraw[Saturday].head(10)
# Out:
#        WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 4811  Saturday  11.0  5.0  CANAL ST_R462_A043_00-00-00       19.0     116.0
# 4812  Saturday  15.0  5.0  CANAL ST_R462_A043_00-00-00       78.0     458.0
# 4813  Saturday  19.0  5.0  CANAL ST_R462_A043_00-00-00      307.0     521.0
# 4814  Saturday  23.0  5.0  CANAL ST_R462_A043_00-00-00      430.0     366.0
# 4815  Saturday   7.0  5.0  CANAL ST_R462_A043_00-00-01       40.0      10.0
# 4816  Saturday  11.0  5.0  CANAL ST_R462_A043_00-00-01       33.0     195.0
# 4817  Saturday  15.0  5.0  CANAL ST_R462_A043_00-00-01       92.0     658.0
# 4818  Saturday  19.0  5.0  CANAL ST_R462_A043_00-00-01      398.0     737.0
# 4819  Saturday  23.0  5.0  CANAL ST_R462_A043_00-00-01      449.0     517.0
# 4820  Saturday   7.0  5.0  CANAL ST_R462_A043_00-00-02       51.0      13.0
#
#       TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME  DOW  Avg/TnStl  \
# ...

# %%
sns.barplot(x = 'HOUR', y = 'TRAFFIC', data = canraw[Saturday])
plt.title('Saturday');

# %%
canraw[Sunday].head(10)
# Out:
#      WEEKDAY  HOUR  dow                     UNIQUEID  ENTRYDIFF  EXITDIFF  \
# 3610  Sunday   3.0  6.0  CANAL ST_R462_A043_00-00-00      130.0      39.0
# 3611  Sunday   7.0  6.0  CANAL ST_R462_A043_00-00-00       27.0       4.0
# 3612  Sunday  11.0  6.0  CANAL ST_R462_A043_00-00-00       21.0      49.0
# 3613  Sunday  15.0  6.0  CANAL ST_R462_A043_00-00-00       91.0     341.0
# 3614  Sunday  19.0  6.0  CANAL ST_R462_A043_00-00-00      212.0     312.0
# 3615  Sunday  23.0  6.0  CANAL ST_R462_A043_00-00-00      305.0     189.0
# 3616  Sunday   3.0  6.0  CANAL ST_R462_A043_00-00-01      177.0      92.0
# 3617  Sunday   7.0  6.0  CANAL ST_R462_A043_00-00-01       34.0       8.0
# 3618  Sunday  11.0  6.0  CANAL ST_R462_A043_00-00-01       24.0      97.0
# 3619  Sunday  15.0  6.0  CANAL ST_R462_A043_00-00-01      116.0     593.0
#
#       TRAFFIC  DURATION  AVG_TRAFFIC       DATETIME  DOW  Avg/TnStl  \
# 3610    169.0       4.0        42.25   5/13/18 1:00  NaN        NaN
# ...

# %%
sns.barplot(x = 'HOUR', y = 'TRAFFIC', data = canraw[Sunday])
plt.title('Sunday');
