# %%
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
station_info = pd.read_csv('station_info_zipcode.csv')

# %%
# station_info

# %%
mta_2018_df = pd.read_pickle('mta_2018')

# %%
mta_2018_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6616743
# 1  REGULAR  6616762
# 2  REGULAR  6616781
# 3  REGULAR  6616886
# 4  REGULAR  6617105
#
#    EXITS
# 0                                            2242108
# 1                                            2242113
# 2                                            2242144
# 3                                            2242229
# 4                                            2242278

# %%
# reset mta data index
mta_2018_df.reset_index(drop=True,inplace=True)

# rename column EXITS
mta_2018_df.rename(columns={'EXITS                                                               ':'EXITS'},inplace=True)

# %%
mta_2018_df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 788281  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788282  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788283  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788284  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788285  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
#
#             TIME     DESC  ENTRIES    EXITS
# 0       00:00:00  REGULAR  6616743  2242108
# 1       04:00:00  REGULAR  6616762  2242113
# 2       08:00:00  REGULAR  6616781  2242144
# 3       12:00:00  REGULAR  6616886  2242229
# 4       16:00:00  REGULAR  6617105  2242278
# ...          ...      ...      ...      ...
# 788281  05:00:00  REGULAR  2919546   387039
# 788282  09:00:00  REGULAR  2919876   387048
# 788283  13:00:00  REGULAR  2920314   387055
# 788284  17:00:00  REGULAR  2920790   387062
# 788285  21:00:00  REGULAR  2921165   387069
#
# [788286 rows x 11 columns]

# %% [markdown]
# # Merge mta data and station zipcode

# %%
# prepare for merging
# Change Stop Name to STATION and convert to all uppercase
station_zipcode_df = station_info[["Stop Name","zip_code"]].copy()
station_zipcode_df["STATION"] = station_zipcode_df['Stop Name'].apply(lambda x: x.upper())
station_zipcode_df.drop(columns=["Stop Name"],inplace=True)

# %%
station_zipcode_df
# Out:
#     zip_code               STATION
# 0      11101  ASTORIA-DITMARS BLVD
# 1      11102          ASTORIA BLVD
# 2      11101                 30 AV
# 3      11101              BROADWAY
# 4      11106                 36 AV
# ..       ...                   ...
# 491    10309          PRINCE'S BAY
# 492    10309       PLEASANT PLAINS
# 493    10307       RICHMOND VALLEY
# 494    10307           TOTTENVILLE
# 495    10307           ARTHUR KILL
#
# [496 rows x 2 columns]

# %%
station_zipcode_df.nunique()
# Out:
# zip_code    140
# STATION     379
# dtype: int64

# %% [markdown]
# ## Multiple zipcodes?

# %%
# some stations have multiple zipcodes
# keep the first one for now. Further investigation?
station_zipcode_unique_df = station_zipcode_df[~station_zipcode_df.STATION.duplicated(keep='first')]
station_zipcode_unique_df.reset_index(drop=True,inplace=True)
station_zipcode_unique_df
# Out:
#     zip_code               STATION
# 0      11101  ASTORIA-DITMARS BLVD
# 1      11102          ASTORIA BLVD
# 2      11101                 30 AV
# 3      11101              BROADWAY
# 4      11106                 36 AV
# ..       ...                   ...
# 374    10309          PRINCE'S BAY
# 375    10309       PLEASANT PLAINS
# 376    10307       RICHMOND VALLEY
# 377    10307           TOTTENVILLE
# 378    10307           ARTHUR KILL
#
# [379 rows x 2 columns]

# %%
station_zipcode_unique_df[station_zipcode_unique_df.STATION == '34 ST-PENN STATION'].zip_code, \
station_zipcode_unique_df[station_zipcode_unique_df.STATION == '23 ST'].zip_code, \
station_zipcode_unique_df[station_zipcode_unique_df.STATION == '86 ST'].zip_code,
# Out:
# (144    10001
#  Name: zip_code, dtype: object,
#  13    10010
#  Name: zip_code, dtype: object,
#  36    11209
#  Name: zip_code, dtype: object)

# %%
station_zipcode_unique_df.STATION.unique()
# Out:
# array(['ASTORIA-DITMARS BLVD', 'ASTORIA BLVD', '30 AV', 'BROADWAY',
#        '36 AV', '39 AV-DUTCH KILLS', 'LEXINGTON AV/59 ST', '5 AV/59 ST',
#        '57 ST-7 AV', '49 ST', 'TIMES SQ-42 ST', '34 ST-HERALD SQ',
#        '28 ST', '23 ST', '14 ST-UNION SQ', '8 ST-NYU', 'PRINCE ST',
#        'CANAL ST', 'CITY HALL', 'CORTLANDT ST', 'RECTOR ST',
#        'WHITEHALL ST-SOUTH FERRY', 'COURT ST', 'JAY ST-METROTECH',
#        'DEKALB AV', 'ATLANTIC AV-BARCLAYS CTR', 'UNION ST', '4 AV-9 ST',
#        'PROSPECT AV', '25 ST', '36 ST', '45 ST', '53 ST', '59 ST',
#        'BAY RIDGE AV', '77 ST', '86 ST', 'BAY RIDGE-95 ST', '7 AV',
#        'PROSPECT PARK', 'PARKSIDE AV', 'CHURCH AV', 'BEVERLEY RD',
#        'CORTELYOU RD', 'NEWKIRK PLAZA', 'AVENUE H', 'AVENUE J',
#        'AVENUE M', 'KINGS HWY', 'AVENUE U', 'NECK RD', 'SHEEPSHEAD BAY',
#        'BRIGHTON BEACH', 'OCEAN PKWY', 'W 8 ST-NY AQUARIUM',
#        'CONEY ISLAND-STILLWELL AV', '9 AV', 'FORT HAMILTON PKWY', '50 ST',
#        '55 ST', '62 ST', '71 ST', '79 ST', '18 AV', '20 AV', 'BAY PKWY',
#        '25 AV', 'BAY 50 ST', '8 AV', 'NEW UTRECHT AV', '121 ST', '111 ST',
#        '104 ST', 'WOODHAVEN BLVD', '85 ST-FOREST PKWY',
#        '75 ST-ELDERTS LN', 'CYPRESS HILLS', 'CRESCENT ST', 'NORWOOD AV',
#        'CLEVELAND ST', 'VAN SICLEN AV', 'ALABAMA AV', 'BROADWAY JUNCTION',
#        'CHAUNCEY ST', 'HALSEY ST', 'GATES AV', 'KOSCIUSZKO ST',
#        'MYRTLE AV', 'FLUSHING AV', 'LORIMER ST', 'HEWES ST', 'MARCY AV',
#        'DELANCEY ST-ESSEX ST', 'BOWERY', 'CHAMBERS ST', 'FULTON ST',
#        'BROAD ST', 'MIDDLE VILLAGE-METROPOLITAN AV', 'FRESH POND RD',
#        'FOREST AV', 'SENECA AV', 'MYRTLE-WYCKOFF AVS', 'KNICKERBOCKER AV',
#        'CENTRAL AV', '6 AV', '14 ST-UNION SQ.', '3 AV', '1 AV',
#        'BEDFORD AV', 'GRAHAM AV', 'GRAND ST', 'MONTROSE AV', 'MORGAN AV',
#        'JEFFERSON ST', 'WILSON AV', 'BUSHWICK AV-ABERDEEN ST',
#        'ATLANTIC AV', 'SUTTER AV', 'LIVONIA AV', 'NEW LOTS AV',
#        'EAST 105 ST', 'CANARSIE-ROCKAWAY PKWY', 'FRANKLIN AV', 'PARK PL',
#        'BOTANIC GARDEN', 'INWOOD-207 ST', 'DYCKMAN ST', '190 ST',
#        '181 ST', '175 ST', '168 ST', '163 ST-AMSTERDAM AV', '155 ST',
#        '145 ST', '135 ST', '125 ST', '116 ST', 'CATHEDRAL PKWY (110 ST)',
#        '103 ST', '96 ST', '81 ST-MUSEUM OF NATURAL HISTORY', '72 ST',
#        '59 ST-COLUMBUS CIRCLE', '42 ST-PORT AUTHORITY BUS TERMINAL',
#        '34 ST-PENN STATION', '14 ST', 'W 4 ST-WASH SQ', 'SPRING ST',
#        'WORLD TRADE CENTER', 'HIGH ST', 'HOYT-SCHERMERHORN STS',
#        'LAFAYETTE AV', 'CLINTON-WASHINGTON AVS', 'NOSTRAND AV',
#        'KINGSTON-THROOP AVS', 'UTICA AV', 'RALPH AV', 'ROCKAWAY AV',
#        'LIBERTY AV', 'SHEPHERD AV', 'EUCLID AV', 'GRANT AV', '80 ST',
#        '88 ST', 'ROCKAWAY BLVD', 'OZONE PARK-LEFFERTS BLVD',
#        'AQUEDUCT RACETRACK', 'AQUEDUCT-N CONDUIT AV',
#        'HOWARD BEACH-JFK AIRPORT', 'BROAD CHANNEL', 'BEACH 90 ST',
#        'BEACH 98 ST', 'BEACH 105 ST', 'ROCKAWAY PARK-BEACH 116 ST',
#        'BEACH 67 ST', 'BEACH 60 ST', 'BEACH 44 ST', 'BEACH 36 ST',
#        'BEACH 25 ST', 'FAR ROCKAWAY-MOTT AV', 'NORWOOD-205 ST',
#        'BEDFORD PARK BLVD', 'KINGSBRIDGE RD', 'FORDHAM RD', '182-183 STS',
#        'TREMONT AV', '174-175 STS', '170 ST', '167 ST',
#        '161 ST-YANKEE STADIUM', '21 ST-QUEENSBRIDGE', 'ROOSEVELT ISLAND',
#        'LEXINGTON AV/63 ST', '57 ST', '47-50 STS-ROCKEFELLER CTR',
#        '42 ST-BRYANT PK', 'BROADWAY-LAFAYETTE ST', '2 AV',
#        'EAST BROADWAY', 'YORK ST', 'BERGEN ST', 'CARROLL ST',
#        'SMITH-9 STS', '15 ST-PROSPECT PARK', 'DITMAS AV', 'AVENUE I',
#        'AVENUE N', 'AVENUE P', 'AVENUE X', 'NEPTUNE AV', 'JAMAICA-179 ST',
#        '169 ST', 'PARSONS BLVD', 'SUTPHIN BLVD', 'BRIARWOOD',
#        'KEW GARDENS-UNION TPKE', '75 AV', 'FOREST HILLS-71 AV', '67 AV',
#        '63 DR-REGO PARK', 'GRAND AV-NEWTOWN', 'ELMHURST AV',
#        'JACKSON HTS-ROOSEVELT AV', '65 ST', 'NORTHERN BLVD', '46 ST',
#        'STEINWAY ST', 'QUEENS PLAZA', 'COURT SQ-23 ST',
#        'LEXINGTON AV/53 ST', '5 AV/53 ST',
#        'JAMAICA CENTER-PARSONS/ARCHER',
#        'SUTPHIN BLVD-ARCHER AV-JFK AIRPORT', 'JAMAICA-VAN WYCK',
#        'COURT SQ', '21 ST', 'GREENPOINT AV', 'NASSAU AV',
#        'METROPOLITAN AV', 'MYRTLE-WILLOUGHBY AVS', 'BEDFORD-NOSTRAND AVS',
#        'CLASSON AV', 'VAN CORTLANDT PARK-242 ST', '238 ST', '231 ST',
#        'MARBLE HILL-225 ST', '215 ST', '207 ST', '191 ST',
#        '168 ST-WASHINGTON HTS', '157 ST', '137 ST-CITY COLLEGE',
#        '116 ST-COLUMBIA UNIVERSITY', '66 ST-LINCOLN CENTER', '18 ST',
#        'CHRISTOPHER ST-SHERIDAN SQ', 'HOUSTON ST', 'FRANKLIN ST',
#        'WTC CORTLANDT', 'SOUTH FERRY', 'PARK PLACE', 'WALL ST',
#        'CLARK ST', 'BOROUGH HALL', 'HOYT ST', 'NEVINS ST',
#        'GRAND ARMY PLAZA', 'EASTERN PKWY-BROOKLYN MUSEUM',
#        'FRANKLIN AVENUE-MEDGAR EVERS COLLEGE', 'KINGSTON AV',
#        'CROWN HTS-UTICA AV', 'SUTTER AV-RUTLAND RD', 'SARATOGA AV',
#        'JUNIUS ST', 'PENNSYLVANIA AV',
#        'PRESIDENT STREET-MEDGAR EVERS COLLEGE', 'STERLING ST',
#        'WINTHROP ST', 'BEVERLY RD', 'NEWKIRK AV',
#        'FLATBUSH AV-BROOKLYN COLLEGE', 'PELHAM BAY PARK', 'BUHRE AV',
#        'MIDDLETOWN RD', 'WESTCHESTER SQ-E TREMONT AV', 'ZEREGA AV',
#        'CASTLE HILL AV', 'PARKCHESTER', 'ST LAWRENCE AV',
#        'MORRISON AV-SOUNDVIEW', 'ELDER AV', 'WHITLOCK AV',
#        'HUNTS POINT AV', 'LONGWOOD AV', 'E 149 ST',
#        "E 143 ST-ST MARY'S ST", 'CYPRESS AV', 'BROOK AV', '3 AV-138 ST',
#        'WOODLAWN', 'MOSHOLU PKWY', 'BEDFORD PARK BLVD-LEHMAN COLLEGE',
#        '183 ST', 'BURNSIDE AV', '176 ST', 'MT EDEN AV',
#        '149 ST-GRAND CONCOURSE', '138 ST-GRAND CONCOURSE', '110 ST',
#        '68 ST-HUNTER COLLEGE', '51 ST', 'GRAND CENTRAL-42 ST', '33 ST',
#        'ASTOR PL', 'BLEECKER ST', 'BROOKLYN BRIDGE-CITY HALL',
#        'BOWLING GREEN', 'WAKEFIELD-241 ST', 'NEREID AV', '233 ST',
#        '225 ST', '219 ST', 'GUN HILL RD', 'BURKE AV', 'ALLERTON AV',
#        'PELHAM PKWY', 'BRONX PARK EAST', 'E 180 ST',
#        'WEST FARMS SQ-E TREMONT AV', '174 ST', 'FREEMAN ST', 'SIMPSON ST',
#        'INTERVALE AV', 'JACKSON AV', '3 AV-149 ST', 'HARLEM-148 ST',
#        'CENTRAL PARK NORTH (110 ST)', 'EASTCHESTER-DYRE AV',
#        'BAYCHESTER AV', 'MORRIS PARK', 'FLUSHING-MAIN ST',
#        'METS-WILLETS POINT', '103 ST-CORONA PLAZA', 'JUNCTION BLVD',
#        '90 ST-ELMHURST AV', '82 ST-JACKSON HTS', '74 ST-BROADWAY',
#        '69 ST', 'WOODSIDE-61 ST', '52 ST', '46 ST-BLISS ST',
#        '40 ST-LOWERY ST', '33 ST-RAWSON ST', 'QUEENSBORO PLAZA',
#        'HUNTERS POINT AV', 'VERNON BLVD-JACKSON AV', '5 AV',
#        '34 ST-HUDSON YARDS', 'ST GEORGE', 'TOMPKINSVILLE', 'STAPLETON',
#        'CLIFTON', 'GRASMERE', 'OLD TOWN', 'DONGAN HILLS', 'JEFFERSON AV',
#        'GRANT CITY', 'NEW DORP', 'OAKWOOD HEIGHTS', 'BAY TERRACE',
#        'GREAT KILLS', 'ELTINGVILLE', 'ANNADALE', 'HUGUENOT',
#        "PRINCE'S BAY", 'PLEASANT PLAINS', 'RICHMOND VALLEY',
#        'TOTTENVILLE', 'ARTHUR KILL'], dtype=object)

# %%
# merge mta and station_info
mta_2018_df.merge(station_zipcode_unique_df, on="STATION", how='left')
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 788281  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788282  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788283  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788284  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788285  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
#
#             TIME     DESC  ENTRIES    EXITS zip_code
# 0       00:00:00  REGULAR  6616743  2242108    11204
# 1       04:00:00  REGULAR  6616762  2242113    11204
# 2       08:00:00  REGULAR  6616781  2242144    11204
# 3       12:00:00  REGULAR  6616886  2242229    11204
# 4       16:00:00  REGULAR  6617105  2242278    11204
# ...          ...      ...      ...      ...      ...
# 788281  05:00:00  REGULAR  2919546   387039      NaN
# 788282  09:00:00  REGULAR  2919876   387048      NaN
# 788283  13:00:00  REGULAR  2920314   387055      NaN
# 788284  17:00:00  REGULAR  2920790   387062      NaN
# 788285  21:00:00  REGULAR  2921165   387069      NaN
#
# [788286 rows x 12 columns]

# %% [markdown]
# # Find entries for each row

# %%
# clean ENTRIES/EXITS as they are cumulative data
mta_2018_df['entries'] = mta_2018_df.ENTRIES.diff()
mta_2018_df['exits'] = mta_2018_df.EXITS.diff()

# %%
mta_2018_df.head(20)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/12/2018  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/13/2018  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/13/2018  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/13/2018  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/13/2018  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/13/2018  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/13/2018  20:00:00
# 12  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/14/2018  00:00:00
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/14/2018  04:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/14/2018  08:00:00
# 15  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/14/2018  12:00:00
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/14/2018  16:00:00
# 17  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/14/2018  20:00:00
# 18  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/15/2018  00:00:00
# 19  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/15/2018  04:00:00
#
#        DESC  ENTRIES    EXITS  entries  exits
# 0   REGULAR  6616743  2242108      NaN    NaN
# 1   REGULAR  6616762  2242113     19.0    5.0
# 2   REGULAR  6616781  2242144     19.0   31.0
# 3   REGULAR  6616886  2242229    105.0   85.0
# 4   REGULAR  6617105  2242278    219.0   49.0
# 5   REGULAR  6617402  2242328    297.0   50.0
# 6   REGULAR  6617539  2242342    137.0   14.0
# 7   REGULAR  6617560  2242345     21.0    3.0
# 8   REGULAR  6617575  2242362     15.0   17.0
# 9   REGULAR  6617674  2242431     99.0   69.0
# 10  REGULAR  6617835  2242469    161.0   38.0
# 11  REGULAR  6618027  2242495    192.0   26.0
# 12  REGULAR  6618116  2242518     89.0   23.0
# 13  REGULAR  6618125  2242521      9.0    3.0
# 14  REGULAR  6618163  2242643     38.0  122.0
# 15  REGULAR  6618300  2242917    137.0  274.0
# 16  REGULAR  6618610  2242987    310.0   70.0
# 17  REGULAR  6619376  2243057    766.0   70.0
# 18  REGULAR  6619545  2243100    169.0   43.0
# 19  REGULAR  6619561  2243101     16.0    1.0

# %%
penn_test_df = mta_2018_df[mta_2018_df.STATION == '34 ST-PENN STA'].iloc[1:16554]

# %% [markdown]
# ## Just testing with penn station data

# %%
penn_filter = penn_test_df[(penn_test_df.entries<3000) & (penn_test_df.entries>0)].copy()

# %%
penn_filter
# Out:
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 50309   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50310   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50311   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50312   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50313   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# ...      ...   ...       ...             ...      ...      ...         ...
# 722622  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722624  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722625  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722626  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722627  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
#
#             TIME     DESC   ENTRIES     EXITS  entries  exits
# 50309   04:00:00  REGULAR   2017955   2033455      6.0    6.0
# 50310   08:00:00  REGULAR   2017983   2033498     28.0   43.0
# 50311   12:00:00  REGULAR   2018078   2033614     95.0  116.0
# 50312   16:00:00  REGULAR   2018228   2033764    150.0  150.0
# 50313   20:00:00  REGULAR   2018333   2033921    105.0  157.0
# ...          ...      ...       ...       ...      ...    ...
# 722622  02:00:00  REGULAR  67647948  17885259     74.0   43.0
# 722624  10:00:00  REGULAR  67648048  17885784    100.0  498.0
# 722625  14:00:00  REGULAR  67648214  17886067    166.0  283.0
# 722626  18:00:00  REGULAR  67648458  17886483    244.0  416.0
# 722627  22:00:00  REGULAR  67648652  17886674    194.0  191.0
#
# [14969 rows x 13 columns]

# %%
penn_filter.entries.mean()
# Out:
# 261.16173425078495

# %%
# convert DATE, TIME to datetime
penn_filter['DateTime'] = pd.to_datetime(penn_filter['DATE'] + " " + penn_filter['TIME'])

# convert TIME to hour
penn_filter['hour'] = pd.to_datetime(penn_filter['TIME'], format='%H:%M:%S').dt.hour

# %%
penn_filter.drop(columns=['DATE','TIME'])
# Out:
#          C/A  UNIT       SCP         STATION LINENAME DIVISION     DESC  \
# 50309   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  REGULAR
# 50310   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  REGULAR
# 50311   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  REGULAR
# 50312   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  REGULAR
# 50313   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  REGULAR
# ...      ...   ...       ...             ...      ...      ...      ...
# 722622  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  REGULAR
# 722624  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  REGULAR
# 722625  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  REGULAR
# 722626  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  REGULAR
# 722627  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  REGULAR
#
#          ENTRIES     EXITS  entries  exits            DateTime  hour
# 50309    2017955   2033455      6.0    6.0 2018-05-12 04:00:00     4
# 50310    2017983   2033498     28.0   43.0 2018-05-12 08:00:00     8
# 50311    2018078   2033614     95.0  116.0 2018-05-12 12:00:00    12
# 50312    2018228   2033764    150.0  150.0 2018-05-12 16:00:00    16
# 50313    2018333   2033921    105.0  157.0 2018-05-12 20:00:00    20
# ...          ...       ...      ...    ...                 ...   ...
# 722622  67647948  17885259     74.0   43.0 2018-06-08 02:00:00     2
# 722624  67648048  17885784    100.0  498.0 2018-06-08 10:00:00    10
# 722625  67648214  17886067    166.0  283.0 2018-06-08 14:00:00    14
# 722626  67648458  17886483    244.0  416.0 2018-06-08 18:00:00    18
# 722627  67648652  17886674    194.0  191.0 2018-06-08 22:00:00    22
#
# [14969 rows x 13 columns]

# %%
# find time_span (hr) for each row
# most are 4.0 hrs but some are not
penn_filter['time_span (hr)'] = penn_filter.DateTime.diff().apply(lambda x: x.total_seconds()/3600)

# %%
penn_filter.head(20)
# Out:
#         C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 50309  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50310  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50311  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50312  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50313  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50314  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# 50315  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# 50316  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# 50317  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# 50318  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# 50319  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# 50320  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/14/2018
# 50321  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/14/2018
# 50322  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/14/2018
# 50323  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/14/2018
# 50324  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/14/2018
# 50325  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/14/2018
# 50326  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/15/2018
# 50327  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/15/2018
# 50328  N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/15/2018
#
#            TIME     DESC  ENTRIES    EXITS  entries  exits  \
# 50309  04:00:00  REGULAR  2017955  2033455      6.0    6.0
# 50310  08:00:00  REGULAR  2017983  2033498     28.0   43.0
# 50311  12:00:00  REGULAR  2018078  2033614     95.0  116.0
# 50312  16:00:00  REGULAR  2018228  2033764    150.0  150.0
# 50313  20:00:00  REGULAR  2018333  2033921    105.0  157.0
# 50314  00:00:00  REGULAR  2018374  2033977     41.0   56.0
# 50315  04:00:00  REGULAR  2018378  2033980      4.0    3.0
# 50316  08:00:00  REGULAR  2018385  2033985      7.0    5.0
# 50317  12:00:00  REGULAR  2018426  2034080     41.0   95.0
# 50318  16:00:00  REGULAR  2018506  2034196     80.0  116.0
# 50319  20:00:00  REGULAR  2018593  2034288     87.0   92.0
# 50320  00:00:00  REGULAR  2018652  2034315     59.0   27.0
# 50321  04:00:00  REGULAR  2018654  2034319      2.0    4.0
# 50322  08:00:00  REGULAR  2018878  2034497    224.0  178.0
# 50323  12:00:00  REGULAR  2019238  2035137    360.0  640.0
# 50324  16:00:00  REGULAR  2019319  2035408     81.0  271.0
# 50325  20:00:00  REGULAR  2019423  2036203    104.0  795.0
# 50326  00:00:00  REGULAR  2019456  2036238     33.0   35.0
# 50327  04:00:00  REGULAR  2019458  2036239      2.0    1.0
# 50328  08:00:00  REGULAR  2019719  2036429    261.0  190.0
#
#                  DateTime  hour  time_span (hr)
# 50309 2018-05-12 04:00:00     4             NaN
# 50310 2018-05-12 08:00:00     8             4.0
# 50311 2018-05-12 12:00:00    12             4.0
# 50312 2018-05-12 16:00:00    16             4.0
# 50313 2018-05-12 20:00:00    20             4.0
# 50314 2018-05-13 00:00:00     0             4.0
# 50315 2018-05-13 04:00:00     4             4.0
# 50316 2018-05-13 08:00:00     8             4.0
# 50317 2018-05-13 12:00:00    12             4.0
# 50318 2018-05-13 16:00:00    16             4.0
# 50319 2018-05-13 20:00:00    20             4.0
# 50320 2018-05-14 00:00:00     0             4.0
# 50321 2018-05-14 04:00:00     4             4.0
# 50322 2018-05-14 08:00:00     8             4.0
# 50323 2018-05-14 12:00:00    12             4.0
# 50324 2018-05-14 16:00:00    16             4.0
# 50325 2018-05-14 20:00:00    20             4.0
# 50326 2018-05-15 00:00:00     0             4.0
# 50327 2018-05-15 04:00:00     4             4.0
# 50328 2018-05-15 08:00:00     8             4.0

# %%
# find ave_entries (entries per hour)
penn_filter['avg_entries'] = penn_filter['entries']/ penn_filter['time_span (hr)']

# %%
penn_filter
# Out:
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 50309   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50310   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50311   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50312   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50313   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# ...      ...   ...       ...             ...      ...      ...         ...
# 722622  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722624  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722625  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722626  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722627  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
#
#             TIME     DESC   ENTRIES     EXITS  entries  exits  \
# 50309   04:00:00  REGULAR   2017955   2033455      6.0    6.0
# 50310   08:00:00  REGULAR   2017983   2033498     28.0   43.0
# 50311   12:00:00  REGULAR   2018078   2033614     95.0  116.0
# 50312   16:00:00  REGULAR   2018228   2033764    150.0  150.0
# 50313   20:00:00  REGULAR   2018333   2033921    105.0  157.0
# ...          ...      ...       ...       ...      ...    ...
# 722622  02:00:00  REGULAR  67647948  17885259     74.0   43.0
# 722624  10:00:00  REGULAR  67648048  17885784    100.0  498.0
# 722625  14:00:00  REGULAR  67648214  17886067    166.0  283.0
# 722626  18:00:00  REGULAR  67648458  17886483    244.0  416.0
# 722627  22:00:00  REGULAR  67648652  17886674    194.0  191.0
#
#                   DateTime  hour  time_span (hr)  avg_entries
# 50309  2018-05-12 04:00:00     4             NaN          NaN
# 50310  2018-05-12 08:00:00     8             4.0         7.00
# 50311  2018-05-12 12:00:00    12             4.0        23.75
# 50312  2018-05-12 16:00:00    16             4.0        37.50
# 50313  2018-05-12 20:00:00    20             4.0        26.25
# ...                    ...   ...             ...          ...
# 722622 2018-06-08 02:00:00     2             4.0        18.50
# 722624 2018-06-08 10:00:00    10             8.0        12.50
# 722625 2018-06-08 14:00:00    14             4.0        41.50
# 722626 2018-06-08 18:00:00    18             4.0        61.00
# 722627 2018-06-08 22:00:00    22             4.0        48.50
#
# [14969 rows x 17 columns]

# %%
# find median_hour (center of the time slot)
penn_filter['median_hour'] = (penn_filter['DateTime'] - (pd.Timedelta(seconds=penn_filter.iloc[1]['time_span (hr)']*3600)/2)).dt.hour

# %%
penn_filter
# Out:
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 50309   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50310   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50311   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50312   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50313   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# ...      ...   ...       ...             ...      ...      ...         ...
# 722622  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722624  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722625  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722626  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722627  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
#
#             TIME     DESC   ENTRIES     EXITS  entries  exits  \
# 50309   04:00:00  REGULAR   2017955   2033455      6.0    6.0
# 50310   08:00:00  REGULAR   2017983   2033498     28.0   43.0
# 50311   12:00:00  REGULAR   2018078   2033614     95.0  116.0
# 50312   16:00:00  REGULAR   2018228   2033764    150.0  150.0
# 50313   20:00:00  REGULAR   2018333   2033921    105.0  157.0
# ...          ...      ...       ...       ...      ...    ...
# 722622  02:00:00  REGULAR  67647948  17885259     74.0   43.0
# 722624  10:00:00  REGULAR  67648048  17885784    100.0  498.0
# 722625  14:00:00  REGULAR  67648214  17886067    166.0  283.0
# 722626  18:00:00  REGULAR  67648458  17886483    244.0  416.0
# 722627  22:00:00  REGULAR  67648652  17886674    194.0  191.0
#
#                   DateTime  hour  time_span (hr)  avg_entries  median_hour
# 50309  2018-05-12 04:00:00     4             NaN          NaN            2
# 50310  2018-05-12 08:00:00     8             4.0         7.00            6
# 50311  2018-05-12 12:00:00    12             4.0        23.75           10
# 50312  2018-05-12 16:00:00    16             4.0        37.50           14
# 50313  2018-05-12 20:00:00    20             4.0        26.25           18
# ...                    ...   ...             ...          ...          ...
# 722622 2018-06-08 02:00:00     2             4.0        18.50            0
# 722624 2018-06-08 10:00:00    10             8.0        12.50            8
# 722625 2018-06-08 14:00:00    14             4.0        41.50           12
# 722626 2018-06-08 18:00:00    18             4.0        61.00           16
# 722627 2018-06-08 22:00:00    22             4.0        48.50           20
#
# [14969 rows x 18 columns]

# %%
penn_filter2 = penn_filter[penn_filter.avg_entries >= 0].copy()

# %%
penn_filter2['day_of_week'] = penn_filter2.DateTime.apply(lambda x: x.weekday())

# %%
penn_filter2
# Out:
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 50310   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50311   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50312   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50313   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50314   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# ...      ...   ...       ...             ...      ...      ...         ...
# 722622  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722624  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722625  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722626  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722627  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
#
#             TIME     DESC   ENTRIES     EXITS  entries  exits  \
# 50310   08:00:00  REGULAR   2017983   2033498     28.0   43.0
# 50311   12:00:00  REGULAR   2018078   2033614     95.0  116.0
# 50312   16:00:00  REGULAR   2018228   2033764    150.0  150.0
# 50313   20:00:00  REGULAR   2018333   2033921    105.0  157.0
# 50314   00:00:00  REGULAR   2018374   2033977     41.0   56.0
# ...          ...      ...       ...       ...      ...    ...
# 722622  02:00:00  REGULAR  67647948  17885259     74.0   43.0
# 722624  10:00:00  REGULAR  67648048  17885784    100.0  498.0
# 722625  14:00:00  REGULAR  67648214  17886067    166.0  283.0
# 722626  18:00:00  REGULAR  67648458  17886483    244.0  416.0
# 722627  22:00:00  REGULAR  67648652  17886674    194.0  191.0
#
#                   DateTime  hour  time_span (hr)  avg_entries  median_hour  \
# 50310  2018-05-12 08:00:00     8             4.0         7.00            6
# 50311  2018-05-12 12:00:00    12             4.0        23.75           10
# 50312  2018-05-12 16:00:00    16             4.0        37.50           14
# 50313  2018-05-12 20:00:00    20             4.0        26.25           18
# 50314  2018-05-13 00:00:00     0             4.0        10.25           22
# ...                    ...   ...             ...          ...          ...
# 722622 2018-06-08 02:00:00     2             4.0        18.50            0
# 722624 2018-06-08 10:00:00    10             8.0        12.50            8
# 722625 2018-06-08 14:00:00    14             4.0        41.50           12
# 722626 2018-06-08 18:00:00    18             4.0        61.00           16
# 722627 2018-06-08 22:00:00    22             4.0        48.50           20
#
#         day_of_week
# 50310             5
# 50311             5
# 50312             5
# 50313             5
# 50314             6
# ...             ...
# 722622            4
# 722624            4
# 722625            4
# 722626            4
# 722627            4
#
# [14592 rows x 19 columns]

# %%
penn_test = penn_filter2.groupby(["day_of_week","median_hour"])['avg_entries'].mean()
penn_avgbyhour = pd.DataFrame(penn_test.groupby('median_hour').sum()).reset_index()
penn_avgbyhour
# Out:
#     median_hour  avg_entries
# 0             0   193.268261
# 1             2    38.926824
# 2             4    63.824667
# 3             6   296.369366
# 4             8  1480.285552
# 5            10   627.657240
# 6            12   704.594102
# 7            14   434.221060
# 8            15   138.738553
# 9            16   863.161831
# 10           17    78.065848
# 11           18   668.407007
# 12           20   678.025007
# 13           22   226.639425

# %%
ax = sns.barplot(x='median_hour', y= 'avg_entries', data = penn_avgbyhour)

# %%
ax = sns.lineplot(x='median_hour', y= 'avg_entries', data = penn_avgbyhour, label='penn station')
ax.legend()

# %%
ax = sns.lineplot(x='hour', y= 'avg_entries', data = penn_filter2, label='penn station')
ax.legend()

# %%
penn_filter2
# Out:
#          C/A  UNIT       SCP         STATION LINENAME DIVISION        DATE  \
# 50310   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50311   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50312   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50313   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/12/2018
# 50314   N067  R012  00-00-00  34 ST-PENN STA      ACE      IND  05/13/2018
# ...      ...   ...       ...             ...      ...      ...         ...
# 722622  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722624  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722625  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722626  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
# 722627  R142  R293  01-06-01  34 ST-PENN STA   123ACE      IRT  06/08/2018
#
#             TIME     DESC   ENTRIES     EXITS  entries  exits  \
# 50310   08:00:00  REGULAR   2017983   2033498     28.0   43.0
# 50311   12:00:00  REGULAR   2018078   2033614     95.0  116.0
# 50312   16:00:00  REGULAR   2018228   2033764    150.0  150.0
# 50313   20:00:00  REGULAR   2018333   2033921    105.0  157.0
# 50314   00:00:00  REGULAR   2018374   2033977     41.0   56.0
# ...          ...      ...       ...       ...      ...    ...
# 722622  02:00:00  REGULAR  67647948  17885259     74.0   43.0
# 722624  10:00:00  REGULAR  67648048  17885784    100.0  498.0
# 722625  14:00:00  REGULAR  67648214  17886067    166.0  283.0
# 722626  18:00:00  REGULAR  67648458  17886483    244.0  416.0
# 722627  22:00:00  REGULAR  67648652  17886674    194.0  191.0
#
#                   DateTime  hour  time_span (hr)  avg_entries  median_hour  \
# 50310  2018-05-12 08:00:00     8             4.0         7.00            6
# 50311  2018-05-12 12:00:00    12             4.0        23.75           10
# 50312  2018-05-12 16:00:00    16             4.0        37.50           14
# 50313  2018-05-12 20:00:00    20             4.0        26.25           18
# 50314  2018-05-13 00:00:00     0             4.0        10.25           22
# ...                    ...   ...             ...          ...          ...
# 722622 2018-06-08 02:00:00     2             4.0        18.50            0
# 722624 2018-06-08 10:00:00    10             8.0        12.50            8
# 722625 2018-06-08 14:00:00    14             4.0        41.50           12
# 722626 2018-06-08 18:00:00    18             4.0        61.00           16
# 722627 2018-06-08 22:00:00    22             4.0        48.50           20
#
#         day_of_week
# 50310             5
# 50311             5
# 50312             5
# 50313             5
# 50314             6
# ...             ...
# 722622            4
# 722624            4
# 722625            4
# 722626            4
# 722627            4
#
# [14592 rows x 19 columns]

# %%
penn_test = penn_filter2.groupby(["day_of_week","median_hour"]).mean()
penn_avgbyhour = pd.DataFrame(penn_test.groupby('median_hour').sum()).reset_index()
penn_avgbyhour
# Out:
#     median_hour       ENTRIES         EXITS      entries        exits   hour  \
# 0             0  5.443706e+08  3.643062e+08   773.073042   566.809991   12.0
# 1             2  1.477111e+08  1.522263e+08   153.188639   109.214605   28.0
# 2             4  5.718177e+08  3.954160e+08   235.734851   198.821099   36.0
# 3             6  1.616016e+08  1.670703e+08  1176.501702   635.038860   56.0
# 4             8  6.645672e+08  4.295733e+08  5922.815333  1775.036061   70.0
# 5            10  1.606881e+08  1.640687e+08  2511.261851  1862.864613   84.0
# 6            12  6.871032e+08  4.360860e+08  2818.587700  1971.414332   98.0
# 7            14  1.647332e+08  1.637189e+08  1726.697162  1913.804699  112.0
# 8            15  5.758091e+06  6.411991e+06   259.846154   610.230769   17.0
# 9            16  6.656031e+08  4.285957e+08  3385.937418  4296.943237  126.0
# 10           17  1.273627e+08  9.067631e+07   132.538462    86.769231   19.0
# 11           18  1.664094e+08  1.638484e+08  2666.812973  3216.923423  140.0
# 12           20  6.859544e+08  4.384256e+08  2691.804373  2503.254315  154.0
# 13           22  1.419403e+08  1.428816e+08   907.066985   684.891455    0.0
#
#     time_span (hr)  avg_entries
# 0        24.000000   193.268261
# 1        30.158585    38.926824
# 2        23.647673    63.824667
# 3        29.135602   296.369366
# 4        31.074346  1480.285552
# 5        29.173904   627.657240
# 6        29.520020   704.594102
# 7        28.487465   434.221060
# 8         1.866004   138.738553
# 9        28.045195   863.161831
# 10        1.697778    78.065848
# 11       28.603692   668.407007
# 12       28.433425   678.025007
# 13       24.127438   226.639425

# %%
ax = sns.lineplot(x='median_hour', y= 'avg_entries', data = penn_avgbyhour, label='penn station')
ax.legend()

# %%
mta_2018_df.STATION.nunique()
# Out:
# 375

# %% [markdown]
# ## end of testing

# %%
mta_2018_df.entries.nlargest(500)
# Out:
# 53398     2.122168e+09
# 250493    2.122146e+09
# 448067    2.122126e+09
# 644814    2.122106e+09
# 125516    2.104403e+09
#               ...
# 560792    2.606461e+08
# 757546    2.606381e+08
# 189310    2.600875e+08
# 387415    2.600613e+08
# 584154    2.600358e+08
# Name: entries, Length: 500, dtype: float64

# %%
mta_2018_df.entries.min()
# Out:
# -2117426867.0

# %%
# find rows that don't make sense

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
mta_2018_df['entries'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
# focus on the majority; exclude outliers
mta_2018_filter_df = mta_2018_df.loc[(mta_2018_df.entries <5000) & (mta_2018_df.entries > 0)]
mta_2018_filter_df["entries"].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
mta_2018_filter_df.entries.mean()
# Out:
# 210.63154483847111

# %% [markdown]
# # Filter entries (make sense?)

# %%
# filter by entries < 3000
mta_2018_filter_df = mta_2018_df.loc[(mta_2018_df.entries <3000) & (mta_2018_df.entries > 0)].copy()

# %% [markdown]
# # Convert date and time

# %%
# convert DATE, TIME to datetime
mta_2018_filter_df['DateTime'] = pd.to_datetime(mta_2018_filter_df['DATE'] + " " + mta_2018_filter_df['TIME'])

# convert TIME to hour
mta_2018_filter_df['hour'] = pd.to_datetime(mta_2018_df['TIME'], format='%H:%M:%S').dt.hour

# %% [markdown]
# # Find daily entries

# %%
daily_entries_all = mta_2018_filter_df.groupby(mta_2018_filter_df['DateTime'].dt.date)['entries'].sum()

# %%
daily_entries_all_df = pd.DataFrame(daily_entries_all)

# %%
daily_entries_all_df.index = pd.to_datetime(daily_entries_all_df.index)

# %%
daily_entries_all_df['day_of_week'] = daily_entries_all_df.index.dayofweek

# %%
daily_entries_all_df.head()
# Out:
#               entries  day_of_week
# DateTime
# 2018-05-12  2710656.0            5
# 2018-05-13  2455129.0            6
# 2018-05-14  5665471.0            0
# 2018-05-15  6123924.0            1
# 2018-05-16  6103955.0            2

# %%
# separte weekday/weekend
daily_entries_all_weekday = daily_entries_all_df[daily_entries_all_df['day_of_week'] < 5]
daily_entries_all_weekend = daily_entries_all_df[daily_entries_all_df['day_of_week'] >= 5]

# %%
# find daily entries by day of week (for all stations)
# Do we want to combine ENTRIES and EXITS?
# Or separate analysis depend on locations and times (residential/commercial)?
# Or just focus on weekdays?
plt.style.use('seaborn')
daily_entries_all_weekday
ax = sns.barplot(x='day_of_week', y= 'entries', data = daily_entries_all_df)

# %% [markdown]
# # Find daily entries for top 10 busy stations
# ### Need to integrate with supplementary data (filtered by zipcode later)?

# %%
daily_entries = mta_2018_filter_df.groupby(['STATION',mta_2018_filter_df['DateTime'].dt.date])['entries'].sum()

# %%
daily_entries
# Out:
# STATION    DateTime
# 1 AV       2018-05-12    14273.0
#            2018-05-13    14273.0
#            2018-05-14    20305.0
#            2018-05-15    22731.0
#            2018-05-16    23475.0
#                           ...
# ZEREGA AV  2018-06-04     2737.0
#            2018-06-05     2789.0
#            2018-06-06     2885.0
#            2018-06-07     2671.0
#            2018-06-08     2748.0
# Name: entries, Length: 10411, dtype: float64

# %%
mta_2018_filter_df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/12/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 788281  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788282  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788283  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788284  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
# 788285  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT  06/08/2018
#
#             TIME     DESC  ENTRIES    EXITS  entries  exits  \
# 1       04:00:00  REGULAR  6616762  2242113     19.0    5.0
# 2       08:00:00  REGULAR  6616781  2242144     19.0   31.0
# 3       12:00:00  REGULAR  6616886  2242229    105.0   85.0
# 4       16:00:00  REGULAR  6617105  2242278    219.0   49.0
# 5       20:00:00  REGULAR  6617402  2242328    297.0   50.0
# ...          ...      ...      ...      ...      ...    ...
# 788281  05:00:00  REGULAR  2919546   387039      5.0    1.0
# 788282  09:00:00  REGULAR  2919876   387048    330.0    9.0
# 788283  13:00:00  REGULAR  2920314   387055    438.0    7.0
# 788284  17:00:00  REGULAR  2920790   387062    476.0    7.0
# 788285  21:00:00  REGULAR  2921165   387069    375.0    7.0
#
#                   DateTime  hour
# 1      2018-05-12 04:00:00     4
# 2      2018-05-12 08:00:00     8
# 3      2018-05-12 12:00:00    12
# 4      2018-05-12 16:00:00    16
# 5      2018-05-12 20:00:00    20
# ...                    ...   ...
# 788281 2018-06-08 05:00:00     5
# 788282 2018-06-08 09:00:00     9
# 788283 2018-06-08 13:00:00    13
# 788284 2018-06-08 17:00:00    17
# 788285 2018-06-08 21:00:00    21
#
# [644954 rows x 15 columns]

# %%
daily_entry_top10 = mta_2018_filter_df.groupby('STATION')['entries'].sum().nlargest(10)
daily_entry_top10
# Out:
# STATION
# 34 ST-PENN STA     3909330.0
# GRD CNTRL-42 ST    3319865.0
# 34 ST-HERALD SQ    2594933.0
# 23 ST              2558026.0
# 14 ST-UNION SQ     2544375.0
# TIMES SQ-42 ST     2432393.0
# FULTON ST          2249493.0
# 42 ST-PORT AUTH    2232884.0
# 86 ST              2008813.0
# 125 ST             1849222.0
# Name: entries, dtype: float64

# %%
daily_entry_top10 = mta_2018_filter_df.groupby(['STATION','day_of_week'])['entries'].sum().groupby('STATION').mean().nlargest(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-204014d56834> in <module>
# ----> 1 daily_entry_top10 = mta_2018_filter_df.groupby(['STATION','day_of_week'])['entries'].sum().groupby('STATION').mean().nlargest(10)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'day_of_week'

# %%
daily_entry_top10_df = pd.DataFrame(daily_entry_top10).reset_index()

# %%
daily_entry_top10_df

# %%
ax = sns.barplot(x = "STATION", y = "entries", data= daily_entry_top10_df)
ax.set_xlabel('Station')
ax.set_ylabel('Entries')
ax.set_xticklabels(daily_entry_top10_df.STATION, rotation=90)

# %% [markdown]
# ### Does weekdays/weekends matter?

# %%
# Separate weekdays/weekends
daily_entries_df['day_of_week'] = daily_entries_df.datetime.dt.dayofweek
daily_entries_weekday = daily_entries_df[daily_entries_df['day_of_week'] < 5]
daily_entries_weekend = daily_entries_df[daily_entries_df['day_of_week'] >= 5]

# %%
# Find busy stations for weekdays
top10_weekday = daily_entries_weekday.groupby(['STATION'])['entries'].mean().nlargest(10)

# %%
pd.DataFrame(daily_entries_weekday.groupby(['STATION'])['entries'].mean())

# %%
top10_weekday_df = pd.DataFrame(top10_weekday).reset_index()

# %%
ax = sns.barplot(x = "STATION", y = "entries", data= top10_weekday_df)
ax.set_xlabel('Station')
ax.set_ylabel('Entries')
ax.set_xticklabels(top10_weekday_df.STATION, rotation=90)

# %%
# Find busy stations for weekends
top10_weekend = daily_entries_weekend.groupby(['STATION'])['entries'].mean().nlargest(10)

# %%
top10_weekend_df = pd.DataFrame(top10_weekend).reset_index()

# %%
ax = sns.barplot(x = "STATION", y = "entries", data= top10_weekend_df)
ax.set_xlabel('Station')
ax.set_ylabel('Entries')
ax.set_xticklabels(top10_weekend_df.STATION, rotation=90)

# %%
# find weekday entries by hours
weekday_hour = mta_2018_df_weekday.groupby("hour")['entries'].mean()
weekday_hour_df = pd.DataFrame(weekday_hour)
ax = sns.barplot(x=weekday_hour_df.index, y="entries", data=weekday_hour_df)

# %%
# find weekend entries by hours
weekend_hour = mta_2018_df_weekend.groupby("hour")['entries'].mean()
weekend_hour_df = pd.DataFrame(weekend_hour)
ax = sns.barplot(x=weekend_hour_df.index, y="entries", data=weekend_hour_df)

# %% [markdown]
# # Find average entries (entries per hour)

# %%
# find time_span (hr) for each row
# most are 4.0 hrs but some are not
mta_2018_filter_df['time_span (hr)'] = mta_2018_filter_df.DateTime.diff().apply(lambda x: x.total_seconds()/3600)

# find ave_entries (entries per hour)
mta_2018_filter_df['avg_entries'] = mta_2018_filter_df['entries']/ mta_2018_filter_df['time_span (hr)']

# %%
mta_2018_filter_df.head()

# %%
mta_2018_filter_df.avg_entries.max()

# %%
# separte weekday/weekend
mta_2018_filter_df['day_of_week'] = mta_2018_filter_df['DateTime'].apply(lambda x: x.weekday())
mta_2018_df_weekday = mta_2018_filter_df[mta_2018_filter_df['day_of_week'] < 5]
mta_2018_df_weekend = mta_2018_filter_df[mta_2018_filter_df['day_of_week'] >= 5]

# %%
# find weekday avg_entries by hours
weekday_hour = mta_2018_df_weekday.groupby("hour")['avg_entries'].mean()
weekday_hour_df = pd.DataFrame(weekday_hour)
ax = sns.barplot(x=weekday_hour_df.index, y="avg_entries", data=weekday_hour_df)

# %%
# find weekend avg_entries by hours
weekend_hour = mta_2018_df_weekend.groupby("hour")['avg_entries'].mean()
weekend_hour_df = pd.DataFrame(weekend_hour)
ax = sns.barplot(x=weekend_hour_df.index, y="avg_entries", data=weekend_hour_df)

# %%
# check time_span and avg_entries make sense?

# %% [markdown]
# # Find top 10 stations (hour, entries)

# %%
weekday_hour_test = mta_2018_df_weekday.groupby(["STATION","hour"])['avg_entries'].mean()
weekday_hour_test_df = pd.DataFrame(weekday_hour_test).reset_index()

# %%
PENN_STA = weekday_hour_test_df[weekday_hour_test_df.STATION == '34 ST-PENN STA']
UNION_SQ = weekday_hour_test_df[weekday_hour_test_df.STATION == '14 ST-UNION SQ']
TIMES_SQ = weekday_hour_test_df[weekday_hour_test_df.STATION == 'TIMES SQ-42 ST']

# %%
ax = sns.lineplot(x= 'hour', y="avg_entries", data=PENN_STA, label = '34 ST-PENN STA')
ax = sns.lineplot(x= 'hour', y="avg_entries", data=UNION_SQ, label = '14 ST-UNION SQ')
ax = sns.lineplot(x= 'hour', y="avg_entries", data=_23_ST, label = 'TIMES_SQ')
ax.legend()

# %% [markdown]
# # Random trials
# ## Find busy stations
# ### Need to integrate with supplementary data by zipcode later?

# %%
# find busiest stations on weekdays
weekday_station = mta_2018_df_weekday.groupby("STATION")['entries'].mean().nlargest(5)
weekday_station_df = pd.DataFrame(weekday_station)
ax = sns.barplot(x=weekday_station_df.index, y="entries", data=weekday_station_df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
# find busiest stations on weekdays
weekend_station = mta_2018_df_weekend.groupby("STATION")['entries'].mean().nlargest(5)
weekend_station_df = pd.DataFrame(weekend_station)
ax = sns.barplot(x=weekend_station_df.index, y="entries", data=weekend_station_df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
weekday_station= mta_2018_df_weekday.groupby("STATION")['avg_entries'].mean().nlargest(5)

# %%
weekday_station

# %% [markdown]
# # test

# %%
mta_2018_filter_df.drop(columns=['entries','exits'],inplace=True)

# %%
mta_2018_df.drop(columns=['entries','exits'],inplace=True)

# %%
mta_2018_df.drop(columns=['day_of_week','hour'],inplace=True)

# %%
mta_2018_filter_df.drop(columns=['day_of_week','hour'],inplace=True)

# %%
from datetime import datetime

# %%
dt1 = datetime(2018,6,8,21,0,0)

# %%
dt2 = datetime(2018,6,9,1,0,0)

# %%
dt1.weekday()

# %%
span = dt2 - dt1

# %%
span.total_seconds()/3600

# %%
mta_2018_filter_df['DESC']+mta_2018_filter_df['TIME']

# %%
# find ENTRIES by day of week
sns.barplot(x='day_of_week', y= 'ENTRIES', data=mta_2018_df)

# %%
# find busiest stations on weekdays/weekends

mta_2018_df_weekday_top5 = mta_2018_df_weekday.groupby(['STATION'])["ENTRIES"].mean().nlargest(5)
mta_2018_df_weekend_top5 = mta_2018_df_weekend.groupby(['STATION'])["ENTRIES"].mean().nlargest(5)

# %%
mta_2018_df_weekday_top5

# %%
plt.hist(x='STATION', data=)

# %%
mta_2018_df_weekend_top5

# %%
# convert TIME to hour
mta_2018_filter_df['hour'] = pd.to_datetime(mta_2018_df['TIME'], format='%H:%M:%S').dt.hour

# %%
ax = sns.barplot(x = daily_entry_top10.index, y = daily_entry_top10.values[::-1], data= daily_entry_top10)
ax.set_xlabel('Station')
ax.set_ylabel('Entries')
ax.set_xticklabels(daily_entry_top10.index, rotation=90)
